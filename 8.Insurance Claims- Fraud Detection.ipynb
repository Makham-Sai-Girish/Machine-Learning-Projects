# %% [raw]
# Problem Statement:
# Business case:
# Insurance fraud is a huge problem in the industry. It's difficult to identify fraud claims. Machine Learning is in a unique position to help the Auto Insurance industry with this problem.
#
# In this project, you are provided a dataset which has the details of the insurance policy along with the customer details. It also has the details of the accident on the basis of which the claims have been made.
#
# In this example, you will be working with some auto insurance data to demonstrate how you can create a predictive model that predicts if an insurance claim is fraudulent or not.

# %%
#import necessary modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Loading and viewing the data
df=pd.read_csv('8.Insurance.csv')
pd.set_option('display.max_columns', None)
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0      250/500               1000                1406.91               0
# 1      250/500               2000                1197.22         5000000
# 2      100/300               2000                1413.14         5000000
# 3      250/500               2000                1415.74         6000000
# 4     500/1000               1000                1583.91         6000000
# ..         ...                ...                    ...             ...
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip insured_sex insured_education_level insured_occupation  \
# 0         466132        MALE                      MD       craft-repair
# 1         468176        MALE                      MD  machine-op-inspct
# 2         430632      FEMALE                     PhD              sales
# 3         608117      FEMALE                     PhD       armed-forces
# 4         610706        MALE               Associate              sales
# ..           ...         ...                     ...                ...
# 995       431289      FEMALE                 Masters       craft-repair
# 996       608177      FEMALE                     PhD     prof-specialty
# 997       442797      FEMALE                 Masters       armed-forces
# 998       441714        MALE               Associate  handlers-cleaners
# 999       612260      FEMALE               Associate              sales
#
#     insured_hobbies insured_relationship  capital-gains  capital-loss  \
# 0          sleeping              husband          53300             0
# 1           reading       other-relative              0             0
# 2       board-games            own-child          35100             0
# 3       board-games            unmarried          48900        -62400
# 4       board-games            unmarried          66000        -46000
# ..              ...                  ...            ...           ...
# 995       paintball            unmarried              0             0
# 996        sleeping                 wife          70900             0
# 997  bungie-jumping       other-relative          35100             0
# 998    base-jumping                 wife              0             0
# 999        kayaking              husband              0             0
#
#     incident_date             incident_type   collision_type  \
# 0      25-01-2015  Single Vehicle Collision   Side Collision
# 1      21-01-2015             Vehicle Theft                ?
# 2      22-02-2015   Multi-vehicle Collision   Rear Collision
# 3      10-01-2015  Single Vehicle Collision  Front Collision
# 4      17-02-2015             Vehicle Theft                ?
# ..            ...                       ...              ...
# 995    22-02-2015  Single Vehicle Collision  Front Collision
# 996    24-01-2015  Single Vehicle Collision   Rear Collision
# 997    23-01-2015   Multi-vehicle Collision   Side Collision
# 998    26-02-2015  Single Vehicle Collision   Rear Collision
# 999    26-02-2015                Parked Car                ?
#
#     incident_severity authorities_contacted incident_state incident_city  \
# 0        Major Damage                Police             SC      Columbus
# 1        Minor Damage                Police             VA     Riverwood
# 2        Minor Damage                Police             NY      Columbus
# 3        Major Damage                Police             OH     Arlington
# 4        Minor Damage                  None             NY     Arlington
# ..                ...                   ...            ...           ...
# 995      Minor Damage                  Fire             NC    Northbrook
# 996      Major Damage                  Fire             SC     Northbend
# 997      Minor Damage                Police             NC     Arlington
# 998      Major Damage                 Other             NY     Arlington
# 999      Minor Damage                Police             WV      Columbus
#
#        incident_location  incident_hour_of_the_day  \
# 0         9935 4th Drive                         5
# 1           6608 MLK Hwy                         8
# 2      7121 Francis Lane                         7
# 3       6956 Maple Drive                         5
# 4           3041 3rd Ave                        20
# ..                   ...                       ...
# 995   6045 Andromedia St                        20
# 996     3092 Texas Drive                        23
# 997          7629 5th St                         4
# 998        6128 Elm Lane                         2
# 999  1416 Cherokee Ridge                         6
#
#      number_of_vehicles_involved property_damage  bodily_injuries  witnesses  \
# 0                              1             YES                1          2
# 1                              1               ?                0          0
# 2                              3              NO                2          3
# 3                              1               ?                1          2
# 4                              1              NO                0          1
# ..                           ...             ...              ...        ...
# 995                            1             YES                0          1
# 996                            1             YES                2          3
# 997                            3               ?                2          3
# 998                            1               ?                0          1
# 999                            1               ?                0          3
#
#     police_report_available  total_claim_amount  injury_claim  property_claim  \
# 0                       YES               71610          6510           13020
# 1                         ?                5070           780             780
# 2                        NO               34650          7700            3850
# 3                        NO               63400          6340            6340
# 4                        NO                6500          1300             650
# ..                      ...                 ...           ...             ...
# 995                       ?               87200         17440            8720
# 996                       ?              108480         18080           18080
# 997                     YES               67500          7500            7500
# 998                     YES               46980          5220            5220
# 999                       ?                5060           460             920
#
#      vehicle_claim   auto_make auto_model  auto_year fraud_reported  _c39
# 0            52080        Saab        92x       2004              Y   NaN
# 1             3510    Mercedes       E400       2007              Y   NaN
# 2            23100       Dodge        RAM       2007              N   NaN
# 3            50720   Chevrolet      Tahoe       2014              Y   NaN
# 4             4550      Accura        RSX       2009              N   NaN
# ..             ...         ...        ...        ...            ...   ...
# 995          61040       Honda     Accord       2006              N   NaN
# 996          72320  Volkswagen     Passat       2015              N   NaN
# 997          52500      Suburu    Impreza       1996              N   NaN
# 998          36540        Audi         A5       1998              N   NaN
# 999           3680    Mercedes       E400       2007              N   NaN
#
# [1000 rows x 40 columns]

# %% [raw]
# There are 40 columns and 1000 rows,
# There are missing values, categorical and continuous data
# Target column - fraud_reported

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
#  13  insured_hobbies              1000 non-null   object
#  14  insured_relationship         1000 non-null   object
#  15  capital-gains                1000 non-null   int64
#  16  capital-loss                 1000 non-null   int64
#  17  incident_date                1000 non-null   object
#  18  incident_type                1000 non-null   object
#  19  collision_type               1000 non-null   object
#  20  incident_severity            1000 non-null   object
#  21  authorities_contacted        1000 non-null   object
#  22  incident_state               1000 non-null   object
#  23  incident_city                1000 non-null   object
#  24  incident_location            1000 non-null   object
#  25  incident_hour_of_the_day     1000 non-null   int64
#  26  number_of_vehicles_involved  1000 non-null   int64
#  27  property_damage              1000 non-null   object
#  28  bodily_injuries              1000 non-null   int64
#  29  witnesses                    1000 non-null   int64
#  30  police_report_available      1000 non-null   object
#  31  total_claim_amount           1000 non-null   int64
#  32  injury_claim                 1000 non-null   int64
#  33  property_claim               1000 non-null   int64
#  34  vehicle_claim                1000 non-null   int64
#  35  auto_make                    1000 non-null   object
#  36  auto_model                   1000 non-null   object
#  37  auto_year                    1000 non-null   int64
#  38  fraud_reported               1000 non-null   object
#  39  _c39                         0 non-null      float64
# dtypes: float64(2), int64(17), object(21)
# memory usage: 312.6+ KB

# %% [markdown]
# By seeing we can drop columns policy_number , _c39 since it is null , no data in it.

# %%
df.drop(['policy_number','_c39'],axis=1, inplace=True)

# %% [markdown]
# we dropped these columns

# %%
#Checking the null values
df.isnull().sum()
# Out:
# months_as_customer             0
# age                            0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# bodily_injuries                0
# witnesses                      0
# police_report_available        0
# total_claim_amount             0
# injury_claim                   0
# property_claim                 0
# vehicle_claim                  0
# auto_make                      0
# auto_model                     0
# auto_year                      0
# fraud_reported                 0
# dtype: int64

# %% [markdown]
# We see there are no missing values, but we seen in the data there are special charecters filled, let us find and replace them

# %% [markdown]
# Checking the columns

# %%
def check(column):
    t=df[column].dtype
    if t=='object':
        sns.countplot(df[column],hue=df['fraud_reported'])
        print(f'unique values in {column} is:',df[column].nunique())
        print(f'unique values in {column} is:',df[column].value_counts())
    else:
        print(f'Brief of {column}:',df[column].describe())
        sns.boxplot(df[column],orient='v')
        print('skewness:',df[column].skew())
        print(f'unique values count in {column}:',df[column].nunique())
    return

# %%
check('months_as_customer')
# Out:
# Brief of months_as_customer: count    1000.000000
# mean      203.954000
# std       115.113174
# min         0.000000
# 25%       115.750000
# 50%       199.500000
# 75%       276.250000
# max       479.000000
# Name: months_as_customer, dtype: float64
# skewness: 0.3621768477780205
# unique values count in months_as_customer: 391

# %% [markdown]
# we can see in average customer is from 204 months and least of 0 months.
# 75% customers are less than 276 months
# there are no outliers,also skewness is in range.

# %%
check('age')
# Out:
# Brief of age: count    1000.000000
# mean       38.948000
# std         9.140287
# min        19.000000
# 25%        32.000000
# 50%        38.000000
# 75%        44.000000
# max        64.000000
# Name: age, dtype: float64
# skewness: 0.47898804709224163
# unique values count in age: 46

# %% [markdown]
# Skewness is acceptable. Min age of client is 19 years, max age is 64. few outliers are present, 50% of the clients are less than age of 38

# %%
#deriving required columns and drop the original column
df['policy_year']=pd.to_datetime(df['policy_bind_date']).dt.year

df['policy_day']=pd.to_datetime(df['policy_bind_date']).dt.day

df['policy_month']=pd.to_datetime(df['policy_bind_date']).dt.month

#dropping the column 
df.drop('policy_bind_date',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_state', 'policy_csl',
#        'policy_deductable', 'policy_annual_premium', 'umbrella_limit',
#        'insured_zip', 'insured_sex', 'insured_education_level',
#        'insured_occupation', 'insured_hobbies', 'insured_relationship',
#        'capital-gains', 'capital-loss', 'incident_date', 'incident_type',
#        'collision_type', 'incident_severity', 'authorities_contacted',
#        'incident_state', 'incident_city', 'incident_location',
#        'incident_hour_of_the_day', 'number_of_vehicles_involved',
#        'property_damage', 'bodily_injuries', 'witnesses',
#        'police_report_available', 'total_claim_amount', 'injury_claim',
#        'property_claim', 'vehicle_claim', 'auto_make', 'auto_model',
#        'auto_year', 'fraud_reported', 'policy_year', 'policy_day',
#        'policy_month'],
#       dtype='object')

# %%
check('policy_state')
# Out:
# unique values in policy_state is: 3
# unique values in policy_state is: OH    352
# IL    338
# IN    310
# Name: policy_state, dtype: int64

# %% [markdown]
# There are 3 policy states, OH,IN, IL - and fraud cases in each state.
# More policies are in state OH , high % of fraud cases in state OH.
# let us encode this column

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['policy_state']=le.fit_transform(df['policy_state'])

# %%
df['policy_state'].value_counts()
# Out:
# 2    352
# 0    338
# 1    310
# Name: policy_state, dtype: int64

# %% [markdown]
# OH is encoded as 2
# IN is encoded as 0
# IL as 1

# %%
check('policy_csl')
# Out:
# unique values in policy_csl is: 3
# unique values in policy_csl is: 250/500     351
# 100/300     349
# 500/1000    300
# Name: policy_csl, dtype: int64

# %%
check('policy_deductable')
# Out:
# Brief of policy_deductable: count    1000.000000
# mean     1136.000000
# std       611.864673
# min       500.000000
# 25%       500.000000
# 50%      1000.000000
# 75%      2000.000000
# max      2000.000000
# Name: policy_deductable, dtype: float64
# skewness: 0.4778872137362794
# unique values count in policy_deductable: 3

# %% [markdown]
# the policy deductables amount 500 - 1000 -2000 avg amount of 1136 isdeducted.

# %%
check('policy_annual_premium')
# Out:
# Brief of policy_annual_premium: count    1000.000000
# mean     1256.406150
# std       244.167395
# min       433.330000
# 25%      1089.607500
# 50%      1257.200000
# 75%      1415.695000
# max      2047.590000
# Name: policy_annual_premium, dtype: float64
# skewness: 0.004401994526610823
# unique values count in policy_annual_premium: 991

# %% [markdown]
# there are some outliers in the premium amount. It is normally distributed.Max. premium amount is 2048

# %%
check('umbrella_limit')
# Out:
# Brief of umbrella_limit: count    1.000000e+03
# mean     1.101000e+06
# std      2.297407e+06
# min     -1.000000e+06
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+07
# Name: umbrella_limit, dtype: float64
# skewness: 1.806712198714504
# unique values count in umbrella_limit: 11

# %% [markdown]
# skewness is more, outliers are present,

# %%
check('insured_zip')
# Out:
# Brief of insured_zip: count      1000.000000
# mean     501214.488000
# std       71701.610941
# min      430104.000000
# 25%      448404.500000
# 50%      466445.500000
# 75%      603251.000000
# max      620962.000000
# Name: insured_zip, dtype: float64
# skewness: 0.8165539258839357
# unique values count in insured_zip: 995

# %% [markdown]
# this is the zip code of location . we doesnt need this column.

# %%
df.drop('insured_zip',axis=1,inplace=True)

# %%
check('insured_sex')
# Out:
# unique values in insured_sex is: 2
# unique values in insured_sex is: FEMALE    537
# MALE      463
# Name: insured_sex, dtype: int64

# %% [markdown]
# Males are more customers and claimed more fraud than female

# %%
#encoding
df['insured_sex']=le.fit_transform(df['insured_sex'])

# %%
check('insured_education_level')
# Out:
# unique values in insured_education_level is: 7
# unique values in insured_education_level is: JD             161
# High School    160
# Associate      145
# MD             144
# Masters        143
# PhD            125
# College        122
# Name: insured_education_level, dtype: int64

# %%
sns.countplot(y=df['insured_education_level'],hue=df['fraud_reported'])

# %% [markdown]
# Educated people also tend to do frauds

# %%
#encoding
df['insured_education_level']=le.fit_transform(df['insured_education_level'])

# %%
check('insured_occupation')
# Out:
# unique values in insured_occupation is: 14
# unique values in insured_occupation is: machine-op-inspct    93
# prof-specialty       85
# tech-support         78
# sales                76
# exec-managerial      76
# craft-repair         74
# transport-moving     72
# other-service        71
# priv-house-serv      71
# armed-forces         69
# adm-clerical         65
# protective-serv      63
# handlers-cleaners    54
# farming-fishing      53
# Name: insured_occupation, dtype: int64

# %%
plt.figure(figsize=(8,8))
sns.countplot(y=df['insured_occupation'],hue=df['fraud_reported'])

# %% [markdown]
# we can see different types of occupations and the fraud claims

# %%
#encoding
df['insured_occupation']=le.fit_transform(df['insured_occupation'])

# %%
check('insured_hobbies')
# Out:
# unique values in insured_hobbies is: 20
# unique values in insured_hobbies is: reading           64
# paintball         57
# exercise          57
# bungie-jumping    56
# golf              55
# movies            55
# camping           55
# kayaking          54
# yachting          53
# hiking            52
# video-games       50
# skydiving         49
# base-jumping      49
# board-games       48
# polo              47
# chess             46
# dancing           43
# sleeping          41
# cross-fit         35
# basketball        34
# Name: insured_hobbies, dtype: int64

# %%
plt.figure(figsize=(8,8))
sns.countplot(y=df['insured_hobbies'],hue=df['fraud_reported'])

# %% [markdown]
# persons with hobbies of chess and cross-fit tend to do more fraud claims

# %%
#encoding
df['insured_hobbies']=le.fit_transform(df['insured_hobbies'])

# %%
check('insured_relationship')
# Out:
# unique values in insured_relationship is: 6
# unique values in insured_relationship is: own-child         183
# other-relative    177
# not-in-family     174
# husband           170
# wife              155
# unmarried         141
# Name: insured_relationship, dtype: int64

# %% [markdown]
# other relation people tend to claim more frauds.

# %%
#encoding
df['insured_relationship']=le.fit_transform(df['insured_relationship'])

# %%
check('capital-gains')
# Out:
# Brief of capital-gains: count      1000.000000
# mean      25126.100000
# std       27872.187708
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%       51025.000000
# max      100500.000000
# Name: capital-gains, dtype: float64
# skewness: 0.4788502295807907
# unique values count in capital-gains: 338

# %% [markdown]
# acceptable skewness,no outliers, max. gain of 100500 and min of 0

# %%
check('capital-loss')
# Out:
# Brief of capital-loss: count      1000.000000
# mean     -26793.700000
# std       28104.096686
# min     -111100.000000
# 25%      -51500.000000
# 50%      -23250.000000
# 75%           0.000000
# max           0.000000
# Name: capital-loss, dtype: float64
# skewness: -0.39147194299389343
# unique values count in capital-loss: 354

# %% [markdown]
# loss itself tends -ve, the values in the column are in negative,let us make them possitive

# %%
df['capital-loss']=abs(df['capital-loss'])

# %%
check('capital-loss')
# Out:
# Brief of capital-loss: count      1000.000000
# mean      26793.700000
# std       28104.096686
# min           0.000000
# 25%           0.000000
# 50%       23250.000000
# 75%       51500.000000
# max      111100.000000
# Name: capital-loss, dtype: float64
# skewness: 0.39147194299389343
# unique values count in capital-loss: 354

# %% [markdown]
# there is  a mean loss of 26793 and max loss of 111100

# %%
check('incident_date')
# Out:
# unique values in incident_date is: 60
# unique values in incident_date is: 02-02-2015    28
# 17-02-2015    26
# 07-01-2015    25
# 04-02-2015    24
# 24-01-2015    24
# 10-01-2015    24
# 19-01-2015    23
# 08-01-2015    22
# 30-01-2015    21
# 13-01-2015    21
# 31-01-2015    20
# 06-02-2015    20
# 22-02-2015    20
# 12-02-2015    20
# 23-02-2015    19
# 14-01-2015    19
# 21-01-2015    19
# 01-01-2015    19
# 21-02-2015    19
# 12-01-2015    19
# 18-01-2015    18
# 25-02-2015    18
# 28-02-2015    18
# 14-02-2015    18
# 01-02-2015    18
# 03-01-2015    18
# 20-01-2015    18
# 24-02-2015    17
# 09-01-2015    17
# 08-02-2015    17
# 26-02-2015    17
# 06-01-2015    17
# 16-02-2015    16
# 16-01-2015    16
# 05-02-2015    16
# 15-02-2015    16
# 13-02-2015    16
# 18-02-2015    15
# 28-01-2015    15
# 15-01-2015    15
# 17-01-2015    15
# 22-01-2015    14
# 27-02-2015    14
# 20-02-2015    14
# 09-02-2015    13
# 03-02-2015    13
# 27-01-2015    13
# 23-01-2015    13
# 01-03-2015    12
# 04-01-2015    12
# 26-01-2015    11
# 02-01-2015    11
# 29-01-2015    11
# 10-02-2015    10
# 07-02-2015    10
# 25-01-2015    10
# 11-02-2015    10
# 19-02-2015    10
# 11-01-2015     9
# 05-01-2015     7
# Name: incident_date, dtype: int64

# %% [markdown]
# majority incidents occured in 2015. this doesn't play any role and also only one year.. so we can drop this column

# %%
df.drop('incident_date',axis=1,inplace=True)

# %%
check('incident_type')
# Out:
# unique values in incident_type is: 4
# unique values in incident_type is: Multi-vehicle Collision     419
# Single Vehicle Collision    403
# Vehicle Theft                94
# Parked Car                   84
# Name: incident_type, dtype: int64

# %% [markdown]
# Majority of single vehicle collision claims are fraudulent

# %%
#encoding
df['incident_type']=le.fit_transform(df['incident_type'])

# %%
check('collision_type')
# Out:
# unique values in collision_type is: 4
# unique values in collision_type is: Rear Collision     292
# Side Collision     276
# Front Collision    254
# ?                  178
# Name: collision_type, dtype: int64

# %% [markdown]
# there is a ? in the values, all the collisions are covered,might be not entered .so let us fill that with mode .. i.e rear collision

# %%
df['collision_type'].replace('?','Rear Collision',inplace=True)

# %%
check('collision_type')
# Out:
# unique values in collision_type is: 3
# unique values in collision_type is: Rear Collision     470
# Side Collision     276
# Front Collision    254
# Name: collision_type, dtype: int64

# %% [markdown]
# we can see majority of fraud claims are rear collisions

# %%
#encoding
df['collision_type']=le.fit_transform(df['collision_type'])

# %%
check('incident_severity')
# Out:
# unique values in incident_severity is: 4
# unique values in incident_severity is: Minor Damage      354
# Total Loss        280
# Major Damage      276
# Trivial Damage     90
# Name: incident_severity, dtype: int64

# %% [markdown]
# major damage claims are fraudulent

# %%
#encoding
df['incident_severity']=le.fit_transform(df['incident_severity'])

# %%
check('authorities_contacted')
# Out:
# unique values in authorities_contacted is: 5
# unique values in authorities_contacted is: Police       292
# Fire         223
# Other        198
# Ambulance    196
# None          91
# Name: authorities_contacted, dtype: int64

# %% [markdown]
# contacted other authorities tends to be more fraudulent,

# %%
#encoding
df['authorities_contacted']=le.fit_transform(df['authorities_contacted'])

# %%
check('incident_state')
# Out:
# unique values in incident_state is: 7
# unique values in incident_state is: NY    262
# SC    248
# WV    217
# VA    110
# NC    110
# PA     30
# OH     23
# Name: incident_state, dtype: int64

# %% [markdown]
# incidents happended in state SC,PH and OH are more fraud claims

# %%
#encoding
df['incident_state']=le.fit_transform(df['incident_state'])

# %%
check('incident_city')
# Out:
# unique values in incident_city is: 7
# unique values in incident_city is: Springfield    157
# Arlington      152
# Columbus       149
# Northbend      145
# Hillsdale      141
# Riverwood      134
# Northbrook     122
# Name: incident_city, dtype: int64

# %% [markdown]
# we already had state detail of incident, so this column might get multicolinearity issue

# %%
#encoding
df['incident_city']=le.fit_transform(df['incident_city'])

# %%
df['incident_location'].nunique()
# Out:
# 1000

# %% [markdown]
# 1000 unique locations, since we have state and city details, we can drop this column

# %%
df.drop('incident_location',axis=1,inplace=True)

# %%
check('incident_hour_of_the_day')
# Out:
# Brief of incident_hour_of_the_day: count    1000.000000
# mean       11.644000
# std         6.951373
# min         0.000000
# 25%         6.000000
# 50%        12.000000
# 75%        17.000000
# max        23.000000
# Name: incident_hour_of_the_day, dtype: float64
# skewness: -0.03558446643823673
# unique values count in incident_hour_of_the_day: 24

# %% [markdown]
# we can see 50% of the incidents occured during day less than 12pm

# %%
sns.countplot(df['incident_hour_of_the_day'],hue=df['fraud_reported'])

# %% [markdown]
# incidents reported at night times 23, 0 and 10am. 14 and 16 hours are tend to be more fraudulent claims

# %%
check('number_of_vehicles_involved')
# Out:
# Brief of number_of_vehicles_involved: count    1000.00000
# mean        1.83900
# std         1.01888
# min         1.00000
# 25%         1.00000
# 50%         1.00000
# 75%         3.00000
# max         4.00000
# Name: number_of_vehicles_involved, dtype: float64
# skewness: 0.502664087487584
# unique values count in number_of_vehicles_involved: 4

# %% [markdown]
# there are 4 vehicles involved max.

# %%
sns.countplot(df['number_of_vehicles_involved'],hue=df['fraud_reported'])

# %% [markdown]
# comparitively 1 , 2 vehicles crash involved are more fraud claims

# %%
check('property_damage')
# Out:
# unique values in property_damage is: 3
# unique values in property_damage is: ?      360
# NO     338
# YES    302
# Name: property_damage, dtype: int64

# %% [markdown]
# ? has the more fraudulent climes, i.e it must be having property damage in report.So replace the ? with Yes

# %%
df['property_damage']=df['property_damage'].replace('?','YES')

# %%
check('property_damage')
# Out:
# unique values in property_damage is: 2
# unique values in property_damage is: YES    662
# NO     338
# Name: property_damage, dtype: int64

# %%
#encoding
df['property_damage']=le.fit_transform(df['property_damage'])

# %%
check('bodily_injuries')
# Out:
# Brief of bodily_injuries: count    1000.000000
# mean        0.992000
# std         0.820127
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max         2.000000
# Name: bodily_injuries, dtype: float64
# skewness: 0.014777103511243209
# unique values count in bodily_injuries: 3

# %%
sns.countplot(df['bodily_injuries'],hue=df['fraud_reported'])

# %% [markdown]
# having 2 injuries are more fradulent

# %%
check('witnesses')
# Out:
# Brief of witnesses: count    1000.000000
# mean        1.487000
# std         1.111335
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         3.000000
# Name: witnesses, dtype: float64
# skewness: 0.019636419856529662
# unique values count in witnesses: 4

# %%
sns.countplot(df['witnesses'],hue=df['fraud_reported'])

# %% [markdown]
# with 2 witness are more fraudulent

# %%
check('police_report_available')
# Out:
# unique values in police_report_available is: 3
# unique values in police_report_available is: ?      343
# NO     343
# YES    314
# Name: police_report_available, dtype: int64

# %% [markdown]
# more fraud will be with no police reports, we will fill the ? with NO

# %%
df['police_report_available'].replace('?','NO',inplace=True)

# %%
check('police_report_available')
# Out:
# unique values in police_report_available is: 2
# unique values in police_report_available is: NO     686
# YES    314
# Name: police_report_available, dtype: int64

# %%
#encoding
df['police_report_available']=le.fit_transform(df['police_report_available'])

# %%
check('total_claim_amount')
# Out:
# Brief of total_claim_amount: count      1000.00000
# mean      52761.94000
# std       26401.53319
# min         100.00000
# 25%       41812.50000
# 50%       58055.00000
# 75%       70592.50000
# max      114920.00000
# Name: total_claim_amount, dtype: float64
# skewness: -0.594581988510234
# unique values count in total_claim_amount: 763

# %% [markdown]
# max claim amount is 114920

# %%
check('auto_make')
# Out:
# unique values in auto_make is: 14
# unique values in auto_make is: Suburu        80
# Saab          80
# Dodge         80
# Nissan        78
# Chevrolet     76
# BMW           72
# Ford          72
# Toyota        70
# Audi          69
# Accura        68
# Volkswagen    68
# Jeep          67
# Mercedes      65
# Honda         55
# Name: auto_make, dtype: int64

# %% [markdown]
# There are different types of cars insured.Frauds are dependent on mentality of person not wrt to car. so we can drop this column

# %%
df.drop('auto_make',axis=1,inplace=True)

# %%
check('auto_model')
# Out:
# unique values in auto_model is: 39
# unique values in auto_model is: RAM               43
# Wrangler          42
# A3                37
# Neon              37
# MDX               36
# Jetta             35
# Passat            33
# A5                32
# Legacy            32
# Pathfinder        31
# Malibu            30
# Camry             28
# Forrestor         28
# 92x               28
# 95                27
# E400              27
# F150              27
# Grand Cherokee    25
# 93                25
# Tahoe             24
# Maxima            24
# Escape            24
# X5                23
# Ultima            23
# Silverado         22
# Civic             22
# Highlander        22
# Fusion            21
# Corolla           20
# CRV               20
# TL                20
# ML350             20
# Impreza           20
# C300              18
# 3 Series          18
# X6                16
# M5                15
# Accord            13
# RSX               12
# Name: auto_model, dtype: int64

# %% [markdown]
# lly we can drop this column also

# %%
df.drop(['auto_model','auto_year'],axis=1,inplace=True)

# %%
plt.figure(figsize=(8,8))
sns.countplot(y=df['policy_year'],hue=df['fraud_reported'])

# %% [markdown]
# Based on the number of years of policy also there is a little chance of predicting fraudulent,

# %% [markdown]
# let us calculate years, in that column from 2015

# %%
df['policy_year']=2015-df['policy_year']

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_state', 'policy_csl',
#        'policy_deductable', 'policy_annual_premium', 'umbrella_limit',
#        'insured_sex', 'insured_education_level', 'insured_occupation',
#        'insured_hobbies', 'insured_relationship', 'capital-gains',
#        'capital-loss', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_hour_of_the_day', 'number_of_vehicles_involved',
#        'property_damage', 'bodily_injuries', 'witnesses',
#        'police_report_available', 'total_claim_amount', 'injury_claim',
#        'property_claim', 'vehicle_claim', 'fraud_reported', 'policy_year',
#        'policy_day', 'policy_month'],
#       dtype='object')

# %% [markdown]
# drop policy day and month

# %%
df.drop(['policy_day','policy_month'],axis=1,inplace=True)

# %%
df.drop('policy_csl',axis=1,inplace=True)

# %%
check('fraud_reported')
# Out:
# unique values in fraud_reported is: 2
# unique values in fraud_reported is: N    753
# Y    247
# Name: fraud_reported, dtype: int64

# %% [markdown]
# 24.7% of claims are fraudulent.it is a huge loss to the insurer company

# %%
#encoding
df['fraud_reported']=le.fit_transform(df['fraud_reported'])

# %%
df['fraud_reported'].value_counts()
# Out:
# 0    753
# 1    247
# Name: fraud_reported, dtype: int64

# %% [markdown]
# No is encoded as 0 and yes as 1

# %%
df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_state                     int32
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_sex                      int32
# insured_education_level          int32
# insured_occupation               int32
# insured_hobbies                  int32
# insured_relationship             int32
# capital-gains                    int64
# capital-loss                     int64
# incident_type                    int32
# collision_type                   int32
# incident_severity                int32
# authorities_contacted            int32
# incident_state                   int32
# incident_city                    int32
# incident_hour_of_the_day         int64
# number_of_vehicles_involved      int64
# property_damage                  int32
# bodily_injuries                  int64
# witnesses                        int64
# police_report_available          int32
# total_claim_amount               int64
# injury_claim                     int64
# property_claim                   int64
# vehicle_claim                    int64
# fraud_reported                   int32
# policy_year                      int64
# dtype: object

# %% [markdown]
# we have seen each column , stat.of column with plots, checked for outliers and skewness also

# %%
#brief stats
df.describe()
# Out:
#        months_as_customer          age  policy_state  policy_deductable  \
# count         1000.000000  1000.000000    1000.00000        1000.000000
# mean           203.954000    38.948000       1.01400        1136.000000
# std            115.113174     9.140287       0.83096         611.864673
# min              0.000000    19.000000       0.00000         500.000000
# 25%            115.750000    32.000000       0.00000         500.000000
# 50%            199.500000    38.000000       1.00000        1000.000000
# 75%            276.250000    44.000000       2.00000        2000.000000
# max            479.000000    64.000000       2.00000        2000.000000
#
#        policy_annual_premium  umbrella_limit  insured_sex  \
# count            1000.000000    1.000000e+03  1000.000000
# mean             1256.406150    1.101000e+06     0.463000
# std               244.167395    2.297407e+06     0.498879
# min               433.330000   -1.000000e+06     0.000000
# 25%              1089.607500    0.000000e+00     0.000000
# 50%              1257.200000    0.000000e+00     0.000000
# 75%              1415.695000    0.000000e+00     1.000000
# max              2047.590000    1.000000e+07     1.000000
#
#        insured_education_level  insured_occupation  insured_hobbies  \
# count              1000.000000         1000.000000      1000.000000
# mean                  2.966000            6.653000         9.731000
# std                   1.948497            4.019048         5.674049
# min                   0.000000            0.000000         0.000000
# 25%                   1.000000            3.000000         5.000000
# 50%                   3.000000            7.000000        10.000000
# 75%                   5.000000           10.000000        15.000000
# max                   6.000000           13.000000        19.000000
#
#        insured_relationship  capital-gains   capital-loss  incident_type  \
# count           1000.000000    1000.000000    1000.000000    1000.000000
# mean               2.416000   25126.100000   26793.700000       1.172000
# std                1.681003   27872.187708   28104.096686       1.081474
# min                0.000000       0.000000       0.000000       0.000000
# 25%                1.000000       0.000000       0.000000       0.000000
# 50%                2.000000       0.000000   23250.000000       1.000000
# 75%                4.000000   51025.000000   51500.000000       2.000000
# max                5.000000  100500.000000  111100.000000       3.000000
#
#        collision_type  incident_severity  authorities_contacted  \
# count     1000.000000        1000.000000            1000.000000
# mean         1.022000           1.184000               2.167000
# std          0.728043           0.939695               1.532142
# min          0.000000           0.000000               0.000000
# 25%          0.000000           0.000000               1.000000
# 50%          1.000000           1.000000               2.000000
# 75%          2.000000           2.000000               4.000000
# max          2.000000           3.000000               4.000000
#
#        incident_state  incident_city  incident_hour_of_the_day  \
# count     1000.000000    1000.000000               1000.000000
# mean         3.242000       2.966000                 11.644000
# std          2.155942       2.044266                  6.951373
# min          0.000000       0.000000                  0.000000
# 25%          1.000000       1.000000                  6.000000
# 50%          4.000000       3.000000                 12.000000
# 75%          5.000000       5.000000                 17.000000
# max          6.000000       6.000000                 23.000000
#
#        number_of_vehicles_involved  property_damage  bodily_injuries  \
# count                   1000.00000      1000.000000      1000.000000
# mean                       1.83900         0.662000         0.992000
# std                        1.01888         0.473265         0.820127
# min                        1.00000         0.000000         0.000000
# 25%                        1.00000         0.000000         0.000000
# 50%                        1.00000         1.000000         1.000000
# 75%                        3.00000         1.000000         2.000000
# max                        4.00000         1.000000         2.000000
#
#          witnesses  police_report_available  total_claim_amount  injury_claim  \
# count  1000.000000              1000.000000          1000.00000   1000.000000
# mean      1.487000                 0.314000         52761.94000   7433.420000
# std       1.111335                 0.464349         26401.53319   4880.951853
# min       0.000000                 0.000000           100.00000      0.000000
# 25%       1.000000                 0.000000         41812.50000   4295.000000
# 50%       1.000000                 0.000000         58055.00000   6775.000000
# 75%       2.000000                 1.000000         70592.50000  11305.000000
# max       3.000000                 1.000000        114920.00000  21450.000000
#
#        property_claim  vehicle_claim  fraud_reported  policy_year
# count     1000.000000    1000.000000     1000.000000  1000.000000
# mean      7399.570000   37928.950000        0.247000    13.396000
# std       4824.726179   18886.252893        0.431483     7.360391
# min          0.000000      70.000000        0.000000     0.000000
# 25%       4445.000000   30292.500000        0.000000     7.000000
# 50%       6750.000000   42100.000000        0.000000    13.000000
# 75%      10885.000000   50822.500000        0.000000    20.000000
# max      23670.000000   79560.000000        1.000000    25.000000

# %% [markdown]
# Only for numerical columns required, just simple display explored and observations noted above for individual column

# %%
df.skew()
# Out:
# months_as_customer             0.362177
# age                            0.478988
# policy_state                  -0.026177
# policy_deductable              0.477887
# policy_annual_premium          0.004402
# umbrella_limit                 1.806712
# insured_sex                    0.148630
# insured_education_level       -0.000148
# insured_occupation            -0.058881
# insured_hobbies               -0.061563
# insured_relationship           0.077488
# capital-gains                  0.478850
# capital-loss                   0.391472
# incident_type                  0.101507
# collision_type                -0.033682
# incident_severity              0.279016
# authorities_contacted         -0.121744
# incident_state                -0.148865
# incident_city                  0.049531
# incident_hour_of_the_day      -0.035584
# number_of_vehicles_involved    0.502664
# property_damage               -0.685977
# bodily_injuries                0.014777
# witnesses                      0.019636
# police_report_available        0.802728
# total_claim_amount            -0.594582
# injury_claim                   0.264811
# property_claim                 0.378169
# vehicle_claim                 -0.621098
# fraud_reported                 1.175051
# policy_year                   -0.052511
# dtype: float64

# %% [markdown]
# we need to remove skewness in the columns
# umbrella limit, tot.Claim amount,vehicle claim

# %%
#check for outliers and removing
from scipy.stats import zscore
z=abs(zscore(df))
df_new=df[(z<3).all(axis=1)]
df_new.shape
# Out:
# (980, 31)

# %%
1-(980/1000)
# Out:
# 0.020000000000000018

# %% [markdown]
# there is a loss of 2% data acceptable

# %%
df_new.skew()
# Out:
# months_as_customer             0.362608
# age                            0.475385
# policy_state                  -0.038157
# policy_deductable              0.476090
# policy_annual_premium          0.035964
# umbrella_limit                 1.801424
# insured_sex                    0.139324
# insured_education_level        0.006286
# insured_occupation            -0.055360
# insured_hobbies               -0.061488
# insured_relationship           0.078339
# capital-gains                  0.466619
# capital-loss                   0.376884
# incident_type                  0.090563
# collision_type                -0.032778
# incident_severity              0.277726
# authorities_contacted         -0.114044
# incident_state                -0.149255
# incident_city                  0.043882
# incident_hour_of_the_day      -0.039280
# number_of_vehicles_involved    0.509725
# property_damage               -0.691993
# bodily_injuries                0.003757
# witnesses                      0.026211
# police_report_available        0.796221
# total_claim_amount            -0.593593
# injury_claim                   0.271759
# property_claim                 0.361356
# vehicle_claim                 -0.620936
# fraud_reported                 1.188267
# policy_year                   -0.065022
# dtype: float64

# %% [markdown]
# still there is skewness, lets remove it

# %%
df_new['umbrella_limit']=np.log(df_new['umbrella_limit']+10)
sns.distplot(df_new['umbrella_limit'])
df_new['umbrella_limit'].skew()
# Out:
# C:\Users\Lucky Girish\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <ipython-input-447-b95eeca54013>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['umbrella_limit']=np.log(df_new['umbrella_limit']+10)
# C:\Users\Lucky Girish\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# 1.5847791899208252

# %% [markdown]
# skewness reduced to 1.6 from 1.8

# %%
df_new['total_claim_amount']=np.square(df_new['total_claim_amount'])
sns.distplot(df_new['total_claim_amount'])
df_new['total_claim_amount'].skew()
# Out:
# <ipython-input-448-6fe4f58404f6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['total_claim_amount']=np.square(df_new['total_claim_amount'])
# 0.5366256297467658

# %% [markdown]
# reduced skewness

# %%
df_new['vehicle_claim']=np.square(df_new['vehicle_claim']+1)
sns.distplot(df_new['vehicle_claim'])
df_new['vehicle_claim'].skew()
# Out:
# <ipython-input-449-8873fde0de17>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['vehicle_claim']=np.square(df_new['vehicle_claim']+1)
# 0.48271142893742414

# %% [markdown]
# reduced skewness

# %%
#correlation
cor=round(df_new.corr(),1)
cor
# Out:
#                              months_as_customer  age  policy_state  \
# months_as_customer                          1.0  0.9          -0.0
# age                                         0.9  1.0          -0.0
# policy_state                               -0.0 -0.0           1.0
# policy_deductable                           0.0  0.0           0.0
# policy_annual_premium                      -0.0  0.0           0.0
# umbrella_limit                              0.0 -0.0          -0.0
# insured_sex                                 0.1  0.1          -0.0
# insured_education_level                    -0.0  0.0          -0.0
# insured_occupation                          0.0  0.0          -0.0
# insured_hobbies                            -0.1 -0.1          -0.0
# insured_relationship                        0.1  0.1          -0.0
# capital-gains                               0.0 -0.0           0.1
# capital-loss                               -0.0 -0.0           0.0
# incident_type                              -0.0 -0.0           0.0
# collision_type                             -0.1 -0.1           0.0
# incident_severity                          -0.1 -0.1          -0.0
# authorities_contacted                       0.0  0.0          -0.0
# incident_state                              0.0  0.0           0.0
# incident_city                              -0.0 -0.0          -0.0
# incident_hour_of_the_day                    0.1  0.1           0.0
# number_of_vehicles_involved                 0.0  0.0          -0.0
# property_damage                            -0.0 -0.0          -0.0
# bodily_injuries                            -0.0 -0.0           0.0
# witnesses                                   0.1  0.1           0.0
# police_report_available                    -0.0 -0.0           0.1
# total_claim_amount                          0.1  0.1          -0.0
# injury_claim                                0.1  0.1          -0.0
# property_claim                              0.0  0.1          -0.0
# vehicle_claim                               0.1  0.1          -0.0
# fraud_reported                              0.0  0.0           0.0
# policy_year                                 0.0  0.0           0.0
#
#                              policy_deductable  policy_annual_premium  \
# months_as_customer                         0.0                   -0.0
# age                                        0.0                    0.0
# policy_state                               0.0                    0.0
# policy_deductable                          1.0                   -0.0
# policy_annual_premium                     -0.0                    1.0
# umbrella_limit                             0.0                   -0.0
# insured_sex                               -0.0                    0.0
# insured_education_level                    0.0                   -0.0
# insured_occupation                        -0.1                    0.0
# insured_hobbies                           -0.0                   -0.0
# insured_relationship                      -0.0                    0.0
# capital-gains                              0.0                   -0.0
# capital-loss                               0.0                   -0.0
# incident_type                             -0.0                    0.1
# collision_type                            -0.1                    0.0
# incident_severity                         -0.0                   -0.0
# authorities_contacted                      0.0                   -0.1
# incident_state                             0.0                    0.0
# incident_city                             -0.0                    0.0
# incident_hour_of_the_day                   0.1                   -0.0
# number_of_vehicles_involved                0.0                   -0.0
# property_damage                            0.0                   -0.0
# bodily_injuries                           -0.0                    0.0
# witnesses                                  0.1                    0.0
# police_report_available                    0.0                    0.0
# total_claim_amount                         0.0                   -0.0
# injury_claim                               0.0                   -0.0
# property_claim                             0.1                   -0.0
# vehicle_claim                             -0.0                    0.0
# fraud_reported                             0.0                   -0.0
# policy_year                                0.1                   -0.0
#
#                              umbrella_limit  insured_sex  \
# months_as_customer                      0.0          0.1
# age                                    -0.0          0.1
# policy_state                           -0.0         -0.0
# policy_deductable                       0.0         -0.0
# policy_annual_premium                  -0.0          0.0
# umbrella_limit                          1.0          0.0
# insured_sex                             0.0          1.0
# insured_education_level                -0.0          0.0
# insured_occupation                      0.0         -0.0
# insured_hobbies                        -0.0         -0.0
# insured_relationship                    0.1          0.0
# capital-gains                          -0.0         -0.0
# capital-loss                            0.0          0.0
# incident_type                           0.0          0.0
# collision_type                          0.0         -0.0
# incident_severity                      -0.0         -0.0
# authorities_contacted                   0.0          0.0
# incident_state                         -0.1         -0.0
# incident_city                           0.0          0.0
# incident_hour_of_the_day               -0.0          0.0
# number_of_vehicles_involved            -0.0          0.0
# property_damage                        -0.0          0.0
# bodily_injuries                         0.1         -0.0
# witnesses                              -0.0          0.0
# police_report_available                -0.0          0.0
# total_claim_amount                     -0.0         -0.0
# injury_claim                           -0.0          0.0
# property_claim                         -0.0         -0.0
# vehicle_claim                          -0.0         -0.0
# fraud_reported                          0.1          0.0
# policy_year                            -0.1          0.0
#
#                              insured_education_level  insured_occupation  \
# months_as_customer                              -0.0                 0.0
# age                                              0.0                 0.0
# policy_state                                    -0.0                -0.0
# policy_deductable                                0.0                -0.1
# policy_annual_premium                           -0.0                 0.0
# umbrella_limit                                  -0.0                 0.0
# insured_sex                                      0.0                -0.0
# insured_education_level                          1.0                -0.0
# insured_occupation                              -0.0                 1.0
# insured_hobbies                                  0.0                -0.0
# insured_relationship                            -0.0                -0.0
# capital-gains                                    0.0                 0.0
# capital-loss                                    -0.0                 0.0
# incident_type                                    0.0                 0.0
# collision_type                                  -0.0                 0.0
# incident_severity                               -0.0                -0.0
# authorities_contacted                           -0.0                -0.0
# incident_state                                  -0.0                -0.0
# incident_city                                   -0.0                 0.0
# incident_hour_of_the_day                        -0.1                -0.0
# number_of_vehicles_involved                      0.0                -0.0
# property_damage                                 -0.1                -0.0
# bodily_injuries                                 -0.0                -0.0
# witnesses                                        0.0                -0.0
# police_report_available                          0.1                -0.0
# total_claim_amount                               0.1                 0.0
# injury_claim                                     0.1                 0.0
# property_claim                                   0.1                 0.0
# vehicle_claim                                    0.1                 0.0
# fraud_reported                                   0.0                 0.0
# policy_year                                     -0.0                 0.0
#
#                              insured_hobbies  insured_relationship  \
# months_as_customer                      -0.1                   0.1
# age                                     -0.1                   0.1
# policy_state                            -0.0                  -0.0
# policy_deductable                       -0.0                  -0.0
# policy_annual_premium                   -0.0                   0.0
# umbrella_limit                          -0.0                   0.1
# insured_sex                             -0.0                   0.0
# insured_education_level                  0.0                  -0.0
# insured_occupation                      -0.0                  -0.0
# insured_hobbies                          1.0                  -0.1
# insured_relationship                    -0.1                   1.0
# capital-gains                            0.1                  -0.0
# capital-loss                             0.0                   0.1
# incident_type                            0.0                   0.0
# collision_type                           0.0                  -0.0
# incident_severity                       -0.0                   0.0
# authorities_contacted                   -0.0                  -0.0
# incident_state                           0.1                  -0.1
# incident_city                            0.0                  -0.0
# incident_hour_of_the_day                 0.0                   0.0
# number_of_vehicles_involved              0.0                  -0.0
# property_damage                          0.0                  -0.0
# bodily_injuries                          0.0                   0.0
# witnesses                               -0.0                  -0.0
# police_report_available                 -0.0                  -0.0
# total_claim_amount                       0.0                   0.0
# injury_claim                             0.0                   0.0
# property_claim                           0.0                   0.0
# vehicle_claim                            0.0                  -0.0
# fraud_reported                          -0.0                   0.0
# policy_year                              0.0                   0.0
#
#                              capital-gains  capital-loss  incident_type  \
# months_as_customer                     0.0          -0.0           -0.0
# age                                   -0.0          -0.0           -0.0
# policy_state                           0.1           0.0            0.0
# policy_deductable                      0.0           0.0           -0.0
# policy_annual_premium                 -0.0          -0.0            0.1
# umbrella_limit                        -0.0           0.0            0.0
# insured_sex                           -0.0           0.0            0.0
# insured_education_level                0.0          -0.0            0.0
# insured_occupation                     0.0           0.0            0.0
# insured_hobbies                        0.1           0.0            0.0
# insured_relationship                  -0.0           0.1            0.0
# capital-gains                          1.0           0.0           -0.0
# capital-loss                           0.0           1.0           -0.0
# incident_type                         -0.0          -0.0            1.0
# collision_type                        -0.0          -0.0           -0.1
# incident_severity                     -0.0           0.0            0.2
# authorities_contacted                 -0.0          -0.0            0.1
# incident_state                         0.0           0.1            0.0
# incident_city                         -0.0           0.0            0.0
# incident_hour_of_the_day              -0.0           0.0           -0.1
# number_of_vehicles_involved            0.1           0.0           -0.9
# property_damage                       -0.0          -0.0            0.0
# bodily_injuries                        0.0           0.0           -0.0
# witnesses                             -0.0           0.0           -0.0
# police_report_available               -0.0           0.0            0.0
# total_claim_amount                     0.0           0.0           -0.2
# injury_claim                           0.0           0.0           -0.2
# property_claim                        -0.0           0.0           -0.2
# vehicle_claim                          0.0           0.0           -0.2
# fraud_reported                        -0.0           0.0           -0.0
# policy_year                           -0.0          -0.0            0.0
#
#                              collision_type  incident_severity  \
# months_as_customer                     -0.1               -0.1
# age                                    -0.1               -0.1
# policy_state                            0.0               -0.0
# policy_deductable                      -0.1               -0.0
# policy_annual_premium                   0.0               -0.0
# umbrella_limit                          0.0               -0.0
# insured_sex                            -0.0               -0.0
# insured_education_level                -0.0               -0.0
# insured_occupation                      0.0               -0.0
# insured_hobbies                         0.0               -0.0
# insured_relationship                   -0.0                0.0
# capital-gains                          -0.0               -0.0
# capital-loss                           -0.0                0.0
# incident_type                          -0.1                0.2
# collision_type                          1.0               -0.0
# incident_severity                      -0.0                1.0
# authorities_contacted                   0.1                0.2
# incident_state                          0.0                0.1
# incident_city                           0.0               -0.0
# incident_hour_of_the_day                0.0               -0.1
# number_of_vehicles_involved             0.1               -0.2
# property_damage                         0.0               -0.1
# bodily_injuries                        -0.0               -0.0
# witnesses                              -0.0               -0.0
# police_report_available                 0.1               -0.0
# total_claim_amount                     -0.0               -0.3
# injury_claim                           -0.0               -0.3
# property_claim                         -0.0               -0.3
# vehicle_claim                          -0.0               -0.3
# fraud_reported                         -0.0               -0.4
# policy_year                            -0.0               -0.0
#
#                              authorities_contacted  incident_state  \
# months_as_customer                             0.0             0.0
# age                                            0.0             0.0
# policy_state                                  -0.0             0.0
# policy_deductable                              0.0             0.0
# policy_annual_premium                         -0.1             0.0
# umbrella_limit                                 0.0            -0.1
# insured_sex                                    0.0            -0.0
# insured_education_level                       -0.0            -0.0
# insured_occupation                            -0.0            -0.0
# insured_hobbies                               -0.0             0.1
# insured_relationship                          -0.0            -0.1
# capital-gains                                 -0.0             0.0
# capital-loss                                  -0.0             0.1
# incident_type                                  0.1             0.0
# collision_type                                 0.1             0.0
# incident_severity                              0.2             0.1
# authorities_contacted                          1.0             0.0
# incident_state                                 0.0             1.0
# incident_city                                 -0.0             0.0
# incident_hour_of_the_day                      -0.1            -0.0
# number_of_vehicles_involved                   -0.1            -0.0
# property_damage                                0.0            -0.0
# bodily_injuries                                0.0            -0.0
# witnesses                                     -0.0             0.0
# police_report_available                        0.0             0.0
# total_claim_amount                            -0.1            -0.0
# injury_claim                                  -0.1            -0.0
# property_claim                                -0.1            -0.0
# vehicle_claim                                 -0.1            -0.0
# fraud_reported                                -0.0            -0.1
# policy_year                                    0.0             0.0
#
#                              incident_city  incident_hour_of_the_day  \
# months_as_customer                    -0.0                       0.1
# age                                   -0.0                       0.1
# policy_state                          -0.0                       0.0
# policy_deductable                     -0.0                       0.1
# policy_annual_premium                  0.0                      -0.0
# umbrella_limit                         0.0                      -0.0
# insured_sex                            0.0                       0.0
# insured_education_level               -0.0                      -0.1
# insured_occupation                     0.0                      -0.0
# insured_hobbies                        0.0                       0.0
# insured_relationship                  -0.0                       0.0
# capital-gains                         -0.0                      -0.0
# capital-loss                           0.0                       0.0
# incident_type                          0.0                      -0.1
# collision_type                         0.0                       0.0
# incident_severity                     -0.0                      -0.1
# authorities_contacted                 -0.0                      -0.1
# incident_state                         0.0                      -0.0
# incident_city                          1.0                       0.0
# incident_hour_of_the_day               0.0                       1.0
# number_of_vehicles_involved           -0.0                       0.1
# property_damage                       -0.0                       0.0
# bodily_injuries                        0.0                      -0.0
# witnesses                              0.0                       0.0
# police_report_available                0.0                       0.0
# total_claim_amount                     0.1                       0.2
# injury_claim                           0.0                       0.2
# property_claim                         0.0                       0.2
# vehicle_claim                          0.1                       0.2
# fraud_reported                        -0.0                       0.0
# policy_year                            0.0                      -0.0
#
#                              number_of_vehicles_involved  property_damage  \
# months_as_customer                                   0.0             -0.0
# age                                                  0.0             -0.0
# policy_state                                        -0.0             -0.0
# policy_deductable                                    0.0              0.0
# policy_annual_premium                               -0.0             -0.0
# umbrella_limit                                      -0.0             -0.0
# insured_sex                                          0.0              0.0
# insured_education_level                              0.0             -0.1
# insured_occupation                                  -0.0             -0.0
# insured_hobbies                                      0.0              0.0
# insured_relationship                                -0.0             -0.0
# capital-gains                                        0.1             -0.0
# capital-loss                                         0.0             -0.0
# incident_type                                       -0.9              0.0
# collision_type                                       0.1              0.0
# incident_severity                                   -0.2             -0.1
# authorities_contacted                               -0.1              0.0
# incident_state                                      -0.0             -0.0
# incident_city                                       -0.0             -0.0
# incident_hour_of_the_day                             0.1              0.0
# number_of_vehicles_involved                          1.0             -0.0
# property_damage                                     -0.0              1.0
# bodily_injuries                                      0.0              0.0
# witnesses                                           -0.0              0.0
# police_report_available                             -0.0              0.0
# total_claim_amount                                   0.2              0.0
# injury_claim                                         0.2              0.0
# property_claim                                       0.2              0.0
# vehicle_claim                                        0.2              0.0
# fraud_reported                                       0.0              0.1
# policy_year                                         -0.0             -0.0
#
#                              bodily_injuries  witnesses  \
# months_as_customer                      -0.0        0.1
# age                                     -0.0        0.1
# policy_state                             0.0        0.0
# policy_deductable                       -0.0        0.1
# policy_annual_premium                    0.0        0.0
# umbrella_limit                           0.1       -0.0
# insured_sex                             -0.0        0.0
# insured_education_level                 -0.0        0.0
# insured_occupation                      -0.0       -0.0
# insured_hobbies                          0.0       -0.0
# insured_relationship                     0.0       -0.0
# capital-gains                            0.0       -0.0
# capital-loss                             0.0        0.0
# incident_type                           -0.0       -0.0
# collision_type                          -0.0       -0.0
# incident_severity                       -0.0       -0.0
# authorities_contacted                    0.0       -0.0
# incident_state                          -0.0        0.0
# incident_city                            0.0        0.0
# incident_hour_of_the_day                -0.0        0.0
# number_of_vehicles_involved              0.0       -0.0
# property_damage                          0.0        0.0
# bodily_injuries                          1.0        0.0
# witnesses                                0.0        1.0
# police_report_available                  0.0        0.1
# total_claim_amount                       0.1       -0.0
# injury_claim                             0.0       -0.0
# property_claim                           0.0        0.0
# vehicle_claim                            0.1       -0.0
# fraud_reported                           0.0        0.0
# policy_year                             -0.0       -0.1
#
#                              police_report_available  total_claim_amount  \
# months_as_customer                              -0.0                 0.1
# age                                             -0.0                 0.1
# policy_state                                     0.1                -0.0
# policy_deductable                                0.0                 0.0
# policy_annual_premium                            0.0                -0.0
# umbrella_limit                                  -0.0                -0.0
# insured_sex                                      0.0                -0.0
# insured_education_level                          0.1                 0.1
# insured_occupation                              -0.0                 0.0
# insured_hobbies                                 -0.0                 0.0
# insured_relationship                            -0.0                 0.0
# capital-gains                                   -0.0                 0.0
# capital-loss                                     0.0                 0.0
# incident_type                                    0.0                -0.2
# collision_type                                   0.1                -0.0
# incident_severity                               -0.0                -0.3
# authorities_contacted                            0.0                -0.1
# incident_state                                   0.0                -0.0
# incident_city                                    0.0                 0.1
# incident_hour_of_the_day                         0.0                 0.2
# number_of_vehicles_involved                     -0.0                 0.2
# property_damage                                  0.0                 0.0
# bodily_injuries                                  0.0                 0.1
# witnesses                                        0.1                -0.0
# police_report_available                          1.0                 0.0
# total_claim_amount                               0.0                 1.0
# injury_claim                                     0.0                 0.8
# property_claim                                   0.0                 0.8
# vehicle_claim                                    0.0                 1.0
# fraud_reported                                  -0.0                 0.1
# policy_year                                      0.0                 0.0
#
#                              injury_claim  property_claim  vehicle_claim  \
# months_as_customer                    0.1             0.0            0.1
# age                                   0.1             0.1            0.1
# policy_state                         -0.0            -0.0           -0.0
# policy_deductable                     0.0             0.1           -0.0
# policy_annual_premium                -0.0            -0.0            0.0
# umbrella_limit                       -0.0            -0.0           -0.0
# insured_sex                           0.0            -0.0           -0.0
# insured_education_level               0.1             0.1            0.1
# insured_occupation                    0.0             0.0            0.0
# insured_hobbies                       0.0             0.0            0.0
# insured_relationship                  0.0             0.0           -0.0
# capital-gains                         0.0            -0.0            0.0
# capital-loss                          0.0             0.0            0.0
# incident_type                        -0.2            -0.2           -0.2
# collision_type                       -0.0            -0.0           -0.0
# incident_severity                    -0.3            -0.3           -0.3
# authorities_contacted                -0.1            -0.1           -0.1
# incident_state                       -0.0            -0.0           -0.0
# incident_city                         0.0             0.0            0.1
# incident_hour_of_the_day              0.2             0.2            0.2
# number_of_vehicles_involved           0.2             0.2            0.2
# property_damage                       0.0             0.0            0.0
# bodily_injuries                       0.0             0.0            0.1
# witnesses                            -0.0             0.0           -0.0
# police_report_available               0.0             0.0            0.0
# total_claim_amount                    0.8             0.8            1.0
# injury_claim                          1.0             0.6            0.7
# property_claim                        0.6             1.0            0.7
# vehicle_claim                         0.7             0.7            1.0
# fraud_reported                        0.1             0.1            0.1
# policy_year                          -0.0             0.0            0.0
#
#                              fraud_reported  policy_year
# months_as_customer                      0.0          0.0
# age                                     0.0          0.0
# policy_state                            0.0          0.0
# policy_deductable                       0.0          0.1
# policy_annual_premium                  -0.0         -0.0
# umbrella_limit                          0.1         -0.1
# insured_sex                             0.0          0.0
# insured_education_level                 0.0         -0.0
# insured_occupation                      0.0          0.0
# insured_hobbies                        -0.0          0.0
# insured_relationship                    0.0          0.0
# capital-gains                          -0.0         -0.0
# capital-loss                            0.0         -0.0
# incident_type                          -0.0          0.0
# collision_type                         -0.0         -0.0
# incident_severity                      -0.4         -0.0
# authorities_contacted                  -0.0          0.0
# incident_state                         -0.1          0.0
# incident_city                          -0.0          0.0
# incident_hour_of_the_day                0.0         -0.0
# number_of_vehicles_involved             0.0         -0.0
# property_damage                         0.1         -0.0
# bodily_injuries                         0.0         -0.0
# witnesses                               0.0         -0.1
# police_report_available                -0.0          0.0
# total_claim_amount                      0.1          0.0
# injury_claim                            0.1         -0.0
# property_claim                          0.1          0.0
# vehicle_claim                           0.1          0.0
# fraud_reported                          1.0         -0.0
# policy_year                            -0.0          1.0

# %% [markdown]
# let us visualize for better understanding

# %%
plt.figure(figsize=(20,20))
sns.heatmap(cor,annot=True)

# %% [markdown]
# observations:
#     Months as customer and age are correlated,we can drop column age
#     incident severity and authorities contacted are corlatred, we will drop authorities as it has less impact on the fraud finding
#     total claim is correlated to injury, vehicle and property claims, so we will drop those three columns

# %%
df_new.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_state', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_hour_of_the_day', 'number_of_vehicles_involved',
#        'property_damage', 'bodily_injuries', 'witnesses',
#        'police_report_available', 'total_claim_amount', 'injury_claim',
#        'property_claim', 'vehicle_claim', 'fraud_reported', 'policy_year'],
#       dtype='object')

# %% [markdown]
# columns are dropped

# %% [markdown]
# let us check still there is any multicollineriaity in the columns and remove them

# %%
from scipy import stats
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calc_vif(x):
    vif=pd.DataFrame()
    vif['variables']=x.columns
    vif['vif factor']=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    return(vif)

# %%
calc_vif(df_new)
# Out:
#                       variables  vif factor
# 0            months_as_customer   23.362830
# 1                           age   95.806347
# 2                  policy_state    2.545662
# 3             policy_deductable    4.586397
# 4         policy_annual_premium   24.815402
# 5                umbrella_limit    1.921167
# 6                   insured_sex    1.913010
# 7       insured_education_level    3.352849
# 8            insured_occupation    3.718690
# 9               insured_hobbies    4.040483
# 10         insured_relationship    3.151027
# 11                capital-gains    1.872870
# 12                 capital-loss    1.966635
# 13                incident_type    8.756910
# 14               collision_type    3.058867
# 15            incident_severity    3.486271
# 16        authorities_contacted    3.220458
# 17               incident_state    3.364449
# 18                incident_city    3.200261
# 19     incident_hour_of_the_day    4.138018
# 20  number_of_vehicles_involved   17.233302
# 21              property_damage    3.001981
# 22              bodily_injuries    2.541561
# 23                    witnesses    2.843009
# 24      police_report_available    1.513325
# 25           total_claim_amount  238.086431
# 26                 injury_claim   19.955565
# 27               property_claim   20.546794
# 28                vehicle_claim  116.817247
# 29               fraud_reported    1.618392
# 30                  policy_year    4.347679

# %%
df_new=df_new.drop(['age','injury_claim','property_claim','vehicle_claim','authorities_contacted','insured_occupation'],axis=1)

# %% [markdown]
# now the columns are dropped, let us check vif again

# %%
calc_vif(df_new)
# Out:
#                       variables  vif factor
# 0            months_as_customer    4.191422
# 1                  policy_state    2.529283
# 2             policy_deductable    4.504852
# 3         policy_annual_premium   21.619467
# 4                umbrella_limit    1.913132
# 5                   insured_sex    1.901642
# 6       insured_education_level    3.307279
# 7               insured_hobbies    3.985647
# 8          insured_relationship    3.102280
# 9                 capital-gains    1.866462
# 10                 capital-loss    1.956265
# 11                incident_type    7.616693
# 12               collision_type    3.025242
# 13            incident_severity    3.203328
# 14               incident_state    3.345126
# 15                incident_city    3.189925
# 16     incident_hour_of_the_day    3.969131
# 17  number_of_vehicles_involved   14.139788
# 18              property_damage    2.959207
# 19              bodily_injuries    2.528583
# 20                    witnesses    2.800372
# 21      police_report_available    1.504453
# 22           total_claim_amount    3.427087
# 23               fraud_reported    1.607360
# 24                  policy_year    4.304561

# %%
df_new=df_new.drop(['incident_type','policy_deductable','insured_relationship','capital-gains','capital-loss'],axis=1)

# %% [markdown]
# dropped columns as they doesnt have relation with finding the frauds

# %%
df_new.shape
# Out:
# (979, 20)

# %% [markdown]
# Now there are 20 columns and 979 rows

# %%
x=df_new.drop('fraud_reported',axis=1)
y=df_new['fraud_reported']

# %%
x.shape
# Out:
# (979, 19)

# %% [markdown]
# 19 columns and 979 rows in x

# %%
y.shape
# Out:
# (979,)

# %% [markdown]
# 979 rows in y

# %%
#scaling the x
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_scaled=sc.fit_transform(x)

# %% [markdown]
# x is now scaled

# %%
#Balancing the dataset
from imblearn.over_sampling import SMOTE
smt=SMOTE()
x_balanced,y_balanced=smt.fit_resample(x_scaled,y)

# %%
#Let us import and split x y at best random state
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
from sklearn.model_selection import train_test_split

lo=LogisticRegression()
rs=0
acsc=0

for i in range(1000):
    x_train,x_test,y_train,y_test=train_test_split(x_balanced,y_balanced,test_size=0.2,random_state=i)
    lo.fit(x_train,y_train)
    pred=lo.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>acsc:
        acsc=acc
        rs=i
print(f'Best score:{acsc}\n random state: {rs}')
# Out:
# Best score:0.8141891891891891
#  random state: 400

# %% [markdown]
# Best accuracy is 81 at random state 400

# %%
x_train,x_test,y_train,y_test=train_test_split(x_balanced,y_balanced,test_size=0.2,random_state=400)

# %%
#importing other models
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

# %%
models=[LogisticRegression(),SVC(),DecisionTreeClassifier(),RandomForestClassifier(),GradientBoostingClassifier(),KNeighborsClassifier()]
for m in models:
    m.fit(x_train,y_train)
    predm=m.predict(x_test)
    print(f'{m}:')
    print('accuracy score:',accuracy_score(y_test,predm))
    print('confusion matrix:\n',confusion_matrix(y_test,predm))
    print('classification report:\n',classification_report(y_test,predm))
    cvscore=cross_val_score(m,x_balanced,y_balanced,cv=5)
    print('mean cv score:',cvscore.mean())
    print('\n')
# Out:
# LogisticRegression():
# accuracy score: 0.8141891891891891
# confusion matrix:
#  [[115  32]
#  [ 23 126]]
# classification report:
#                precision    recall  f1-score   support
#
#            N       0.83      0.78      0.81       147
#            Y       0.80      0.85      0.82       149
#
#     accuracy                           0.81       296
#    macro avg       0.82      0.81      0.81       296
# weighted avg       0.82      0.81      0.81       296
#
# mean cv score: 0.7469651855245076
#
#
# SVC():
# accuracy score: 0.8445945945945946
# confusion matrix:
#  [[123  24]
#  [ 22 127]]
# classification report:
#                precision    recall  f1-score   support
#
#            N       0.85      0.84      0.84       147
#            Y       0.84      0.85      0.85       149
#
#     accuracy                           0.84       296
#    macro avg       0.84      0.84      0.84       296
# weighted avg       0.84      0.84      0.84       296
#
# mean cv score: 0.8437585890975722
#
#
# DecisionTreeClassifier():
# accuracy score: 0.8277027027027027
# confusion matrix:
#  [[112  35]
#  [ 16 133]]
# classification report:
#                precision    recall  f1-score   support
#
#            N       0.88      0.76      0.81       147
#            Y       0.79      0.89      0.84       149
#
#     accuracy                           0.83       296
#    macro avg       0.83      0.83      0.83       296
# weighted avg       0.83      0.83      0.83       296
#
# mean cv score: 0.8336051305542831
#
#
# RandomForestClassifier():
# accuracy score: 0.9054054054054054
# confusion matrix:
#  [[134  13]
#  [ 15 134]]
# classification report:
#                precision    recall  f1-score   support
#
#            N       0.90      0.91      0.91       147
#            Y       0.91      0.90      0.91       149
#
#     accuracy                           0.91       296
#    macro avg       0.91      0.91      0.91       296
# weighted avg       0.91      0.91      0.91       296
#
# mean cv score: 0.8803137883646359
#
#
# GradientBoostingClassifier():
# accuracy score: 0.8952702702702703
# confusion matrix:
#  [[132  15]
#  [ 16 133]]
# classification report:
#                precision    recall  f1-score   support
#
#            N       0.89      0.90      0.89       147
#            Y       0.90      0.89      0.90       149
#
#     accuracy                           0.90       296
#    macro avg       0.90      0.90      0.90       296
# weighted avg       0.90      0.90      0.90       296
#
# mean cv score: 0.8735249656436098
#
#
# KNeighborsClassifier():
# accuracy score: 0.7567567567567568
# confusion matrix:
#  [[ 86  61]
#  [ 11 138]]
# classification report:
#                precision    recall  f1-score   support
#
#            N       0.89      0.59      0.70       147
#            Y       0.69      0.93      0.79       149
#
#     accuracy                           0.76       296
#    macro avg       0.79      0.76      0.75       296
# weighted avg       0.79      0.76      0.75       296
#
# mean cv score: 0.7456413192853871

# %% [markdown]
# DTC, SVC has same cv score and f1 score, RF has some less difference but more accuracy score than these two also less faults by checking confusion matrix.Let us check for the RF model by tuning to improve accuracy

# %%
#Hyper parameter tuning of Ridge regression
from sklearn.model_selection import GridSearchCV

par={'n_estimators':range(100,500,100),'criterion':['gini','entropy'],'max_depth':range(0,10,5),'min_samples_split':range(2,20,4),
     'min_samples_leaf':range(1,5),'max_features':['auto']}

grid=GridSearchCV(RandomForestClassifier(),param_grid=par,verbose=2,n_jobs=1)
grid.fit(x_train,y_train)
print("Best score:",grid.best_score_)
print("Best estimator:",grid.best_estimator_)
print("Best parameters:",grid.best_params_)
# Out:
# Fitting 5 folds for each of 320 candidates, totalling 1600 fits
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   0.2s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   0.2s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   0.2s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=6, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=300; total time=   0.2s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=300; total time=   0.2s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=300; total time=   0.2s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=400; total time=   0.2s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=14, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=18, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=18, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=18, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=18, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=18, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=18, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=18, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=18, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=18, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=18, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=18, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=18, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=18, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=18, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=1, min_samples_split=18, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.3s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   0.2s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   0.2s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   0.2s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   0.2s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=300; total time=   0.2s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=400; total time=   0.2s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=400; total time=   0.2s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=400; total time=   0.3s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=14, n_estimators=400; total time=   0.3s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=18, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=18, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=18, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=18, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=18, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=18, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=18, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=18, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=18, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=18, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=18, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=18, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=18, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=18, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=2, min_samples_split=18, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=6, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=6, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=6, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=6, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=6, n_estimators=400; total time=   0.2s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=6, n_estimators=400; total time=   0.2s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=6, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=6, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=6, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=10, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=14, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=14, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=14, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=14, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=14, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=14, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=14, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=14, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=14, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=14, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=14, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=14, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=14, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=14, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=14, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=14, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=14, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=14, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=14, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=14, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=18, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=18, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=18, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=18, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=18, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=18, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=18, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=18, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=18, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=18, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=18, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=18, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=18, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=18, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=18, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=3, min_samples_split=18, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=400; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.1s
# [CV] END criterion=gini, max_depth=0, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.0s
# ...
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=300; total time=   1.1s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=300; total time=   1.1s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=300; total time=   1.1s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=400; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=400; total time=   1.7s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=400; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=400; total time=   1.0s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=6, n_estimators=400; total time=   1.0s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.7s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.7s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.7s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.7s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=   0.7s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   0.9s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   1.0s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   1.2s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   0.9s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   0.9s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=300; total time=   0.7s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=300; total time=   0.7s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=300; total time=   0.7s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=300; total time=   0.7s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=300; total time=   0.7s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=400; total time=   0.9s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=400; total time=   0.9s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=400; total time=   0.9s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=400; total time=   0.9s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=14, n_estimators=400; total time=   1.0s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=18, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=18, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=18, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=18, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=18, n_estimators=100; total time=   0.2s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=18, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=18, n_estimators=200; total time=   0.5s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=18, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=18, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=18, n_estimators=200; total time=   0.4s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=18, n_estimators=300; total time=   0.7s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=18, n_estimators=300; total time=   0.7s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=18, n_estimators=300; total time=   0.7s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=18, n_estimators=300; total time=   0.7s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=18, n_estimators=300; total time=   0.7s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=18, n_estimators=400; total time=   1.0s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=18, n_estimators=400; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=18, n_estimators=400; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=18, n_estimators=400; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=4, min_samples_split=18, n_estimators=400; total time=   1.5s
# C:\Users\Lucky Girish\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 800 fits failed out of a total of 1600.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 800 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Lucky Girish\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Lucky Girish\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 441, in fit
#     trees = Parallel(
#   File "C:\Users\Lucky Girish\anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\Lucky Girish\anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\Lucky Girish\anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\Lucky Girish\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\Lucky Girish\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\Lucky Girish\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\Lucky Girish\anaconda3\lib\site-packages\joblib\parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\Lucky Girish\anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 209, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\Lucky Girish\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 184, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\Lucky Girish\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\Lucky Girish\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 306, in fit
#     raise ValueError("max_depth must be greater than zero. ")
# ValueError: max_depth must be greater than zero.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Lucky Girish\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.83754917 0.83077666 0.83247157 0.83163127
#  0.82570264 0.83332261 0.83331188 0.83078023 0.83330115 0.82570264
#  0.8324823  0.82993993 0.82654652 0.82739755 0.83077666 0.8299292
#  0.82909247 0.8299435  0.82993635 0.82824501 0.82739755 0.82655367
#  0.82825216 0.82824144 0.82825931 0.83078738 0.8273904  0.83077666
#  0.81979547 0.82994708 0.83077666 0.83332261 0.82908532 0.83331545
#  0.83078023 0.83162411 0.8350211  0.83163484 0.82824144 0.82824859
#  0.82909247 0.83333691 0.83078381 0.82740471 0.82908889 0.82993635
#  0.82740113 0.83331545 0.83246442 0.82571337 0.8299292  0.83078023
#  0.82571337 0.82570979 0.82653937 0.82824501 0.82400772 0.82739398
#  0.82993635 0.82909247 0.8299435  0.82825216 0.82908889 0.82401845
#  0.82485876 0.83332618 0.82740113 0.83416291 0.83332261 0.8273904
#  0.82569906 0.82993993 0.82486591 0.82656082 0.8299292  0.82909247
#  0.82570979 0.82993993 0.82740113 0.82569906        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.82993635 0.83162769 0.83163127 0.8265501  0.82995781 0.83078023
#  0.83416291 0.82655367 0.83164557 0.83078381 0.82739755 0.83077308
#  0.82571694 0.82909605 0.82909605 0.82739398 0.82486948 0.82655367
#  0.83078381 0.82487306 0.82824144 0.83415934 0.82993993 0.83162769
#  0.82825574 0.83246442 0.83078023 0.83331545 0.82908532 0.83077666
#  0.82148681 0.83078381 0.8240113  0.82570979 0.82909605 0.82824144
#  0.82739755 0.83416291 0.82656798 0.82485876 0.82908889 0.82907817
#  0.82656082 0.82824859 0.82908532 0.83077308 0.8240113  0.82908889
#  0.8299292  0.83078023 0.82739755 0.83077666 0.82316384 0.83164199
#  0.83077308 0.82825216 0.82909962 0.83078023 0.82400772 0.82824144
#  0.82995065 0.82570264 0.82908889 0.82993278 0.83162769 0.83331545
#  0.82824501 0.8299292  0.8240113  0.8265501  0.82572052 0.82908532
#  0.8358471  0.82571337 0.82824859 0.82909247 0.83162769 0.82400772
#  0.82740113 0.82993635]
#   warnings.warn(
# Best score: 0.8375491668454552
# Best estimator: RandomForestClassifier(max_depth=5)
# Best parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}

# %%
rf=RandomForestClassifier(criterion='gini', max_depth=100, min_samples_leaf=3,
                       min_samples_split=5,max_features='auto',n_estimators=100,random_state=400)
rf.fit(x_train,y_train)
pred=rf.predict(x_test)
print('accuracy:',accuracy_score(y_test,pred))
print('confusion matrix:',confusion_matrix(y_test,pred))
print('classification report:',classification_report(y_test,pred))
# Out:
# accuracy: 0.918918918918919
# confusion matrix: [[134  13]
#  [ 11 138]]
# classification report:               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.92       147
#            1       0.91      0.93      0.92       149
#
#     accuracy                           0.92       296
#    macro avg       0.92      0.92      0.92       296
# weighted avg       0.92      0.92      0.92       296

# %% [markdown]
# accuracy improved from 90 to 92%

# %%
results=pd.DataFrame({'Actual':y_test,'Predicted':pred})
results
# Out:
#       Actual  Predicted
# 1262       1          1
# 796        0          0
# 519        0          0
# 1314       1          1
# 988        1          1
# ...      ...        ...
# 12         0          0
# 1043       1          1
# 178        1          1
# 781        0          1
# 490        1          1
#
# [296 rows x 2 columns]

# %%
#Auc Roc curve
from sklearn.metrics import roc_auc_score
#Predicting the probability of having 0 in the x-test
y_pred_prob=rf.predict_proba(x_test)[:,1]
y_pred_prob

#Visualising
from sklearn.metrics import roc_curve
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)

plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='KNeighborsClassifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()
auc_score=roc_auc_score(y_test,rf.predict(x_test))
print('Score:',auc_score)
# Out:
# Score: 0.9188695612473178

# %% [markdown]
# AUC ROC score is 92%

# %%
#Saving the model
import joblib
joblib.dump(rf,'Insurance_fraud.obj')
# Out:
# ['Insurance_fraud.obj']
